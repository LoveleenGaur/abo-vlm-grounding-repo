# %%
# !nvidia-smi -L
# !pip -q install "transformers==4.51.3" "accelerate==1.6.0" pillow requests
# !git clone https://github.com/LoveleenGaur/abo-vlm-grounding-repo.git
# %cd abo-vlm-grounding-repo
# Out:
# GPU 0: Tesla T4 (UUID: GPU-98513a75-1e91-acd7-8fe6-3c9fa2028186)
# Cloning into 'abo-vlm-grounding-repo'...
# remote: Enumerating objects: 61, done.
# remote: Counting objects: 100% (61/61), done.
# remote: Compressing objects: 100% (59/59), done.
# Receiving objects: 100% (61/61), 732.35 KiB | 2.07 MiB/s, done.
# remote: Total 61 (delta 19), reused 0 (delta 0), pack-reused 0 (from 0)
# Resolving deltas: 100% (19/19), done.
# /content/abo-vlm-grounding-repo/abo-vlm-grounding-repo/abo-vlm-grounding-repo

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-24e24b04-abf9-44ea-ab10-1754b1240993" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-24e24b04-abf9-44ea-ab10-1754b1240993">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !python run_third_model.py
# Out:
# manifest: 150 products, 40 types  ->  results/manifest.csv
# third model: Phi-3.5-Vision (4.2B)  [microsoft/Phi-3.5-vision-instruct]
# resolving image paths ...
# 150 products with images
# device: cuda
# to generate: 450 of 450
# 2026-08-08 23:27:20.702410: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# processor_config.json: 100% 119/119 [00:00<00:00, 677kB/s]
# processing_phi3_v.py: 22.0kB [00:00, 60.5MB/s]
# A new version of the following files was downloaded from https://huggingface.co/microsoft/Phi-3.5-vision-instruct:
# - processing_phi3_v.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# ...

# %%
# !pip uninstall -y transformers
# !pip install -q transformers==4.43.0 accelerate==0.30.0
# Out:
# Found existing installation: transformers 4.51.3
# Uninstalling transformers-4.51.3:
#   Successfully uninstalled transformers-4.51.3
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.7/43.7 kB 4.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.4/9.4 MB 103.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.4/302.4 kB 32.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 127.8 MB/s eta 0:00:00

# %%
# %cd /content/abo-vlm-grounding-repo
# Out:
# /content/abo-vlm-grounding-repo

# %%
import transformers
print(transformers.__version__)
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]
# 4.43.0

# %%
# !rm -f results/gen_phi35-vision-4b.jsonl

# %%
# !python run_third_model.py
# Out:
# python3: can't open file '/content/abo-vlm-grounding-repo/run_third_model.py': [Errno 2] No such file or directory

# %%
# %cd /content
# !rm -rf abo-vlm-grounding-repo
# !git clone https://github.com/LoveleenGaur/abo-vlm-grounding-repo.git
# %cd abo-vlm-grounding-repo
# !ls
# Out:
# /content
# Cloning into 'abo-vlm-grounding-repo'...
# remote: Enumerating objects: 61, done.
# remote: Counting objects: 100% (61/61), done.
# remote: Compressing objects: 100% (59/59), done.
# Receiving objects: 100% (61/61), 732.35 KiB | 2.25 MiB/s, done.
# remote: Total 61 (delta 19), reused 0 (delta 0), pack-reused 0 (from 0)
# Resolving deltas: 100% (19/19), done.
# /content/abo-vlm-grounding-repo
# CITATION.cff  LICENSE	README.md	  results
# data	      notebook	requirements.txt  run_third_model.py

# %%
# !rm -f results/gen_phi35-vision-4b.jsonl
# !python run_third_model.py
# Out:
# manifest: 150 products, 40 types  ->  results/manifest.csv
# third model: Phi-3.5-Vision (4.2B)  [microsoft/Phi-3.5-vision-instruct]
# resolving image paths ...
# 150 products with images
# device: cuda
# to generate: 450 of 450
# 2026-08-08 23:36:57.700324: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /usr/local/lib/python3.12/dist-packages/transformers/models/auto/image_processing_auto.py:513: FutureWarning: The image_processor_class argument is deprecated and will be removed in v4.42. Please use `slow_image_processor_class`, or `fast_image_processor_class` instead
#   warnings.warn(
# Loading checkpoint shards: 100% 2/2 [00:27<00:00, 13.94s/it]
# ...

# %%
from google.colab import files
files.download("/content/abo-vlm-grounding-repo/results/scored_all.csv")

# %%
files.download("/content/abo-vlm-grounding-repo/results/gen_phi35-vision-4b.jsonl")

# %%
# !pip freeze > /content/abo-vlm-grounding-repo/environment_colab.txt

# %%
files.download("/content/abo-vlm-grounding-repo/environment_colab.txt")

# %%
run_info = """
Experiment: Third-model ABO VLM grounding study
Model: microsoft/Phi-3.5-vision-instruct
Model label: Phi-3.5-Vision (4.2B)
Products: 150
Conditions: 3
Total third-model generations: 450
Python: 3.12.13
Transformers: 4.43.0
Torch: 2.11.0+cu128

Integrity checks:
qwen2vl-2b: MATCH
smolvlm-500m: MATCH

Phi-3.5-Vision preview:
usable paired n = 87
coverage image_only = 0.306
coverage image+metadata = 0.850
grounding delta = +0.544
paired d = 2.03
prompting scaffold delta = +0.008
paired d = 0.05

Final combined rows = 1350
New Phi-3.5 rows = 450
"""

with open("/content/abo-vlm-grounding-repo/RUN_INFO.txt", "w") as f:
    f.write(run_info)

# %%
files.download("/content/abo-vlm-grounding-repo/RUN_INFO.txt")
